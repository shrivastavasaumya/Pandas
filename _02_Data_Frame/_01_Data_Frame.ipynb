# %%
import pandas as pd

# Creating a DataFrame
data = {
    "Name": ["John", "Alice", "Bob"],
    "Age": [25, 30, 22],
    "Marks": [85, 90, 78]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age  Marks
# 0   John   25     85
# 1  Alice   30     90
# 2    Bob   22     78

# %%
df   # for proper visualization
# Out:
#     Name  Age  Marks
# 0   John   25     85
# 1  Alice   30     90
# 2    Bob   22     78
