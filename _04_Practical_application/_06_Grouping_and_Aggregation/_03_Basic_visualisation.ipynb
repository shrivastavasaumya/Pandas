# %%
import pandas as pd
df = pd.read_csv("employee_data.csv")

# %%
df['Age'].hist()       # histogram of 'age'
# Out:
# <Axes: >

# %%
df['Age'].plot()
# Out:
# <Axes: >

# %%
# age and salary relation

df.plot(kind = 'scatter', x = "Age", y = "Salary")
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>
